# %% [markdown]
# # CIFAR-10 Classification Example
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. CIFAR-10 dataset is directly available in TensorFlow. This example shows how to train a simple CNN for classification.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # Reduce TF verbosity
import tensorflow as tf
tf.get_logger().setLevel('INFO') # Reduce TF verbosity

import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dropout, Dense, GlobalMaxPooling2D, BatchNormalization, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
import numpy as np
import utils

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalize colors
x_train, x_test = x_train/255.0, x_test/255.0
y_train, y_test = y_train.flatten(), y_test.flatten()

# Find the number of classes
K = np.unique(y_train.flatten()).size

# Print input size and number of classes
print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"number of classes: {K}")
# Out:
# x_train shape: (50000, 32, 32, 3)
# y_train shape: (50000,)
# number of classes: 10

# %%
# Input
i = Input(shape=x_train[0].shape)

#--- Old Model ---
#x = Conv2D(32, (3, 3), strides=2, activation='relu')(i)
#x = Conv2D(64, (3, 3), strides=2, activation='relu')(x)
#x = Conv2D(128, (3, 3), strides=2, activation='relu')(x)

#--- New Model ---
x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
#---------
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
#---------
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

# Fully connected layers
x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(K, activation='softmax')(x)

# Create the model
model = tf.keras.Model(i, x)

# Print model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,343,018
# Trainable params: 1,342,122
# Non-trainable params: 896
# _________________________________________________________________

# %%
# Create the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Use image data generator for data augmentation
data_generator = ImageDataGenerator(
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    zoom_range = [0.9, 1.1],
    rotation_range = 10,
#    brightness_range = [0.9, 1.1],
    horizontal_flip = True
)

# Define batch size
batch_size = 256

# Define data generator and steps per training and validation
train_generator = data_generator.flow(x_train, y_train)
steps_per_epoch = x_train.shape[0] // batch_size
validation_steps = x_test.shape[0] // batch_size

# Fit the model
r = model.fit(
    train_generator,
    validation_data = (x_test, y_test), 
    steps_per_epoch = steps_per_epoch,
    validation_steps = validation_steps,
    epochs=40
)
# Out:
# Epoch 1/40
# 195/195 [==============================] - 6s 24ms/step - loss: 2.1465 - accuracy: 0.3114 - val_loss: 2.7575 - val_accuracy: 0.1160
# Epoch 2/40
# 195/195 [==============================] - 4s 21ms/step - loss: 1.6702 - accuracy: 0.3909 - val_loss: 2.5262 - val_accuracy: 0.2186
# Epoch 3/40
# 195/195 [==============================] - 4s 21ms/step - loss: 1.5563 - accuracy: 0.4351 - val_loss: 1.5079 - val_accuracy: 0.4659
# Epoch 4/40
# 195/195 [==============================] - 4s 21ms/step - loss: 1.4538 - accuracy: 0.4683 - val_loss: 1.4123 - val_accuracy: 0.4987
# Epoch 5/40
# 195/195 [==============================] - 4s 21ms/step - loss: 1.3730 - accuracy: 0.5101 - val_loss: 1.8778 - val_accuracy: 0.4226
# Epoch 6/40
# 195/195 [==============================] - 4s 22ms/step - loss: 1.3229 - accuracy: 0.5245 - val_loss: 1.6639 - val_accuracy: 0.4578
# Epoch 7/40
# 195/195 [==============================] - 4s 22ms/step - loss: 1.2759 - accuracy: 0.5412 - val_loss: 1.5802 - val_accuracy: 0.4869
# Epoch 8/40
# 195/195 [==============================] - 4s 20ms/step - loss: 1.1925 - accuracy: 0.5689 - val_loss: 1.1997 - val_accuracy: 0.5738
# Epoch 9/40
# 195/195 [==============================] - 4s 21ms/step - loss: 1.1767 - accuracy: 0.5846 - val_loss: 1.3622 - val_accuracy: 0.5593
# Epoch 10/40
# 195/195 [==============================] - 4s 21ms/step - loss: 1.1341 - accuracy: 0.5920 - val_loss: 1.2192 - val_accuracy: 0.5796
# Epoch 11/40
# 195/195 [==============================] - 4s 21ms/step - loss: 1.1075 - accuracy: 0.6011 - val_loss: 1.3257 - val_accuracy: 0.5579
# Epoch 12/40
# 195/195 [==============================] - 4s 21ms/step - loss: 1.0524 - accuracy: 0.6284 - val_loss: 1.2196 - val_accuracy: 0.5805
# Epoch 13/40
# 195/195 [==============================] - 4s 21ms/step - loss: 1.0463 - accuracy: 0.6385 - val_loss: 1.0212 - val_accuracy: 0.6418
# Epoch 14/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.9979 - accuracy: 0.6465 - val_loss: 0.9312 - val_accuracy: 0.6758
# Epoch 15/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.9988 - accuracy: 0.6516 - val_loss: 1.0287 - val_accuracy: 0.6508
# Epoch 16/40
# 195/195 [==============================] - 4s 22ms/step - loss: 0.9883 - accuracy: 0.6551 - val_loss: 1.0598 - val_accuracy: 0.6422
# Epoch 17/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.9591 - accuracy: 0.6670 - val_loss: 1.0969 - val_accuracy: 0.6477
# Epoch 18/40
# 195/195 [==============================] - 4s 22ms/step - loss: 0.9270 - accuracy: 0.6800 - val_loss: 1.2383 - val_accuracy: 0.5895
# Epoch 19/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8889 - accuracy: 0.6888 - val_loss: 0.9231 - val_accuracy: 0.6813
# Epoch 20/40
# 195/195 [==============================] - 4s 22ms/step - loss: 0.9113 - accuracy: 0.6854 - val_loss: 0.8667 - val_accuracy: 0.7039
# Epoch 21/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.9202 - accuracy: 0.6724 - val_loss: 0.9422 - val_accuracy: 0.6830
# Epoch 22/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8733 - accuracy: 0.7038 - val_loss: 1.0967 - val_accuracy: 0.6482
# Epoch 23/40
# 195/195 [==============================] - 4s 20ms/step - loss: 0.8639 - accuracy: 0.7000 - val_loss: 1.0798 - val_accuracy: 0.6457
# Epoch 24/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8379 - accuracy: 0.7101 - val_loss: 1.1668 - val_accuracy: 0.6220
# Epoch 25/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8366 - accuracy: 0.7131 - val_loss: 0.8567 - val_accuracy: 0.7148
# Epoch 26/40
# 195/195 [==============================] - 4s 22ms/step - loss: 0.8645 - accuracy: 0.7011 - val_loss: 0.9328 - val_accuracy: 0.6829
# Epoch 27/40
# 195/195 [==============================] - 4s 22ms/step - loss: 0.8258 - accuracy: 0.7125 - val_loss: 0.8722 - val_accuracy: 0.7102
# Epoch 28/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.8056 - accuracy: 0.7221 - val_loss: 0.8765 - val_accuracy: 0.7072
# Epoch 29/40
# 195/195 [==============================] - 4s 22ms/step - loss: 0.7918 - accuracy: 0.7351 - val_loss: 0.8299 - val_accuracy: 0.7193
# Epoch 30/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.7826 - accuracy: 0.7269 - val_loss: 0.8447 - val_accuracy: 0.7125
# Epoch 31/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.7762 - accuracy: 0.7319 - val_loss: 0.8491 - val_accuracy: 0.7191
# Epoch 32/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.7780 - accuracy: 0.7343 - val_loss: 0.8851 - val_accuracy: 0.7164
# Epoch 33/40
# 195/195 [==============================] - 4s 22ms/step - loss: 0.7390 - accuracy: 0.7391 - val_loss: 1.0370 - val_accuracy: 0.6897
# Epoch 34/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.7459 - accuracy: 0.7418 - val_loss: 0.7789 - val_accuracy: 0.7405
# Epoch 35/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.7691 - accuracy: 0.7429 - val_loss: 0.7845 - val_accuracy: 0.7436
# Epoch 36/40
# 195/195 [==============================] - 4s 21ms/step - loss: 0.7326 - accuracy: 0.7535 - val_loss: 0.7137 - val_accuracy: 0.7609
# Epoch 37/40
# 195/195 [==============================] - 4s 22ms/step - loss: 0.7143 - accuracy: 0.7567 - val_loss: 0.8506 - val_accuracy: 0.7228
# Epoch 38/40
# 195/195 [==============================] - 4s 22ms/step - loss: 0.7311 - accuracy: 0.7503 - val_loss: 0.6953 - val_accuracy: 0.7653
# Epoch 39/40
# 195/195 [==============================] - 4s 22ms/step - loss: 0.6942 - accuracy: 0.7633 - val_loss: 0.7095 - val_accuracy: 0.7651
# Epoch 40/40
# 195/195 [==============================] - 4s 22ms/step - loss: 0.6925 - accuracy: 0.7575 - val_loss: 0.8526 - val_accuracy: 0.7379

# %%
# Plot training- and cross-validation losses
plt.plot(r.history['loss'], label='Training loss')
plt.plot(r.history['val_loss'], label='Validation loss')
plt.legend()

# %%
# Plot training- and cross-validation accuracy
plt.plot(r.history['accuracy'], label='Training acc')
plt.plot(r.history['val_accuracy'], label='Validation accuracy')
plt.legend()

# %%
# Names corresponding to the classes
labels = '''airplane
automobile
bird
cat
deer
dog
frog
horse
ship
truck'''.split()

# Predict
p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
utils.plot_confusion_matrix(cm, labels)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %%
# Show examples of misclassified images with class names
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i], cmap='gray')
print(f"True label: {y_test[i]}")
print(f"Classified label: {p_test[i]}")
plt.title("True label: %s, classified label: %s" % (labels[y_test.flatten()[i]], labels[p_test.flatten()[i]]))
# Out:
# True label: 7
# Classified label: 6
# Text(0.5, 1.0, 'True label: horse, classified label: frog')
